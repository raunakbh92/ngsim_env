# %% [markdown]
# - Trying out lateral velocity command
# - Will be needed to use Zach's planner output with automotive driving models
# - Adapted from AutomotiveDrivingModels docs/2D stadium
# - Learnings
#     - Scene is a list of vehicles. For example `veh1 = scene[1]`
#     works perfectly
#     - Record is what enables visualization
#     - LatLonAccel seems to have inbuilt lane follower as seen from the stadium roadway testing in this file
#     - Tabling that now and focusing only on the straight roadways case
#     - AccelTurnrate does not have this inherent lane following capability built in

# %%
using AutomotiveDrivingModels
using AutoViz

# %% [markdown]
# # Straight roadway
# - To avoid the issue caused by inherent lane following that many conflate things on curved stadium roadway wherein we wont be sure whether car is being driven by commaded lateral acceleration on inherent lane follower

# %%
roadway = gen_straight_roadway(3,200.0)
# Out:
# Roadway

# %%
scene = Scene()
push!(scene,Vehicle(VehicleState(
            VecSE2(10.0,-DEFAULT_LANE_WIDTH,0.0),roadway, 29.0),
        VehicleDef(), 1))
push!(scene,Vehicle(VehicleState(
            VecSE2(40.0,0.0,0.0), roadway, 22.0),
        VehicleDef(), 2))
push!(scene,Vehicle(VehicleState(
            VecSE2(70.0,-DEFAULT_LANE_WIDTH,0.0),roadway, 27.0),
        VehicleDef(), 3))
@show scene[1].state.v

car_colors = get_pastel_car_colors(scene)
cam = FitToContentCamera()

rec = SceneRecord(200,0.1,200)
vehnum = 2 # Governs which vehicle in the scene is being controlled
for step in 1:0.1:10
    lat_vel_cmd = 1.0
    dt = 0.1
    phi = scene[vehnum].state.posF.ϕ
    v = scene[vehnum].state.v
    lat_accel = (2/(dt*dt))*(lat_vel_cmd*dt - v*sin(phi)*dt)
    
    updated_state = propagate(scene[vehnum],LatLonAccel(lat_accel,0.0),
        roadway,dt)
    scene[1] = Entity(scene[1],propagate(scene[1],
            LatLonAccel(0.0,0.0),roadway,dt))
    scene[3] = Entity(scene[3],propagate(scene[3],
            LatLonAccel(0.0,0.0),roadway,dt))
    #@show updated_state
    
    #@show scene[1].state
    
    updated_veh = Entity(scene[vehnum],updated_state)
    
    
    scene[vehnum] = updated_veh
    #@show scene[1].state
    
    AutomotiveDrivingModels.update!(rec,scene)
    render(scene, roadway, cam=cam, car_colors=car_colors)
end
# Out:
# scene[1].state.v = 29.0

# %%
using Interact
@manipulate for frame_index in 1 : nframes(rec)
    render(rec[frame_index-nframes(rec)], roadway,
        cam=cam, car_colors=car_colors)
end
# Out:
# (div
# ...

# %% [markdown]
# # Stadium roadway
# - LatLonAccel seems to have a lane follower embedded within as seen by running the code below
# - Tabling this issue for now as the roadways we are looking at for now are fairly straight

# %%
roadway = gen_stadium_roadway(3)
# Out:
# Roadway

# %%
scene = Scene()
push!(scene,Vehicle(VehicleState(VecSE2(10.0,-DEFAULT_LANE_WIDTH,0.0), 
            roadway, 29.0), VehicleDef(), 1))
push!(scene,Vehicle(VehicleState(VecSE2(40.0,0.0,0.0), roadway, 22.0), 
        VehicleDef(), 2))
push!(scene,Vehicle(VehicleState(VecSE2(70.0,-DEFAULT_LANE_WIDTH,0.0),
            roadway, 27.0), VehicleDef(), 3))

car_colors = get_pastel_car_colors(scene)
cam = FitToContentCamera()

rec = SceneRecord(200,0.1,200)
veh3 = scene[3]
for step in 1:1:100
    # find new action
    #latvel = 1
    #lalacc = #logic to find accele command from vel
    #@show step

    # update the veh state with this action
    lat_vel_cmd = 1.0
#     lat_accel = (2/(dt*dt))*(lat_vel_cmd*dt - v*sin(phi)*dt)
    updated_state = propagate(scene[3],AccelTurnrate(0.0,0.0),roadway,0.1)
    
    updated_state = propagate(scene[3],LatLonAccel(0.0,0.0),roadway,0.1)
    
    #@show updated_state
    
    #@show scene[1].state
    
    updated_veh = Entity(scene[3],updated_state)
    
    
    scene[3] = updated_veh
    #@show scene[1].state
    
    AutomotiveDrivingModels.update!(rec,scene)
    render(scene, roadway, cam=cam, car_colors=car_colors)
end

# %%
using Interact
@manipulate for frame_index in 1 : nframes(rec)
    render(rec[frame_index-nframes(rec)], roadway,
        cam=cam, car_colors=car_colors)
end
# Out:
# (div
# ...
